# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !jupyter nbconvert --to script '/content/drive/MyDrive/git/utils/ipynb/explode_tokens.ipynb' \
--output '/content/drive/MyDrive/git/utils/py/explode_tokens'
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/git/utils/ipynb/explode_tokens.ipynb to script
# [NbConvertApp] Writing 2252 bytes to /content/drive/MyDrive/git/utils/py/explode_tokens.py

# %%
import sys
sys.path.append('/content/drive/MyDrive/git/utils/')
