# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !jupyter nbconvert --to script '/content/drive/MyDrive/git/plotly_utils/ipynb/custom_plotly_template.ipynb' \
--output '/content/drive/MyDrive/git/plotly_utils/py/custom_plotly_template'
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/git/plotly_utils/ipynb/custom_plotly_template.ipynb to script
# [NbConvertApp] Writing 2130 bytes to /content/drive/MyDrive/git/plotly_utils/py/custom_plotly_template.py

# %%
import sys
sys.path.append('/content/drive/MyDrive/git/utils/')

# %%
base_dir = os.path.join('..', 'content', 'drive', 'MyDrive', 'git')
file_path = os.path.join(base_dir, 'utils', 'py')
modules = os.path.join(base_dir, file_path)
sys.path.append(os.path.abspath(modules))
